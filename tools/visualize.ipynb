# %%
# For interactive matplotlib, refers to:
# https://stackoverflow.com/questions/38364435/python-matplotlib-make-3d-plot-interactive-in-jupyter-notebook
# %matplotlib notebook
# %matplotlib widget

import matplotlib.pyplot as plt
import pickle

# %%
with open('../ray_origin_scatters_dataposes_vs_videoposes_llff.fig.pickle', 'rb') as file:
    fig3d = pickle.load(file)
fig3d.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
with open('../ray_dir_scatters_dataposes_vs_videoposes_llff.fig.pickle', 'rb') as file:
    fig3d = pickle.load(file)
ax3d = plt.gca()
ax3d.set_xlim([-0.5, 0.1])
ax3d.set_ylim([0, 0.5])
ax3d.set_zlim([0, 1.2])
fig3d.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import pickle
with open('../ray_origin_scatters_dataposes_vs_videoposes_blender.fig.pickle', 'rb') as file:
    fig3d = pickle.load(file)
fig3d.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
with open('../ray_dir_scatters_dataposes_vs_videoposes_blender.fig.pickle', 'rb') as file:
    fig3d = pickle.load(file)
fig3d.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
